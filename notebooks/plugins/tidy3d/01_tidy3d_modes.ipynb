# %% [markdown]
# # Tidy3D mode solver
#
# ## Waveguides

# %%
import gdsfactory.simulation.gtidy3d as gt

nm = 1e-3
# Out:
# 2022-09-10 15:57:57.916 | INFO     | gdsfactory.config:<module>:53 - Load '/home/runner/work/gdsfactory/gdsfactory/gdsfactory' 5.28.0
# 2022-09-10 15:58:01.014 | INFO     | gdsfactory.simulation.gtidy3d:<module>:54 - Tidy3d '1.6.1' installed at ['/usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d']

# %%
strip = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
strip.plot_index()

# %%
strip.plot_Ex(0)  # TE
strip.plot_Ey(1)  # TM
# Out:
# 2022-09-10 15:58:01.397 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/534e038e.npz mode data from file cache.

# %%
rib = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.15,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
rib.plot_index()

# %%
rib.plot_Ex(mode_index=0)
rib.plot_Ey(mode_index=0)
# Out:
# 2022-09-10 15:58:02.688 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bf8ecbd9.npz mode data from file cache.

# %%
nitride = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=1.0,
    wg_thickness=0.4,
    slab_thickness=0.0,
    ncore=gt.modes.sin,
    nclad=gt.modes.sio2,
)
nitride.plot_index()
nitride.plot_Ex(0)
nitride.plot_Ey(0)
# Out:
# 2022-09-10 15:58:03.801 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/7b92a943.npz mode data from file cache.

# %% [markdown]
# ## Sweep width
#
# You can sweep the waveguide width and compute the modes.

# %%
df = gt.modes.sweep_width(
    width1=200 * nm,
    width2=1000 * nm,
    steps=11,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
gt.modes.plot_sweep_width(
    width1=200 * nm,
    width2=1000 * nm,
    steps=11,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2022-09-10 15:58:04.689 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/cbc69aad.npz mode data from file cache.
# 2022-09-10 15:58:04.791 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d88e531c.npz mode data from file cache.
# 2022-09-10 15:58:04.896 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bfe27829.npz mode data from file cache.
# 2022-09-10 15:58:04.995 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/b604ff01.npz mode data from file cache.
# 2022-09-10 15:58:05.101 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/6453e781.npz mode data from file cache.
# 2022-09-10 15:58:05.209 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/701c0cac.npz mode data from file cache.
# 2022-09-10 15:58:05.307 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/5d807a39.npz mode data from file cache.
# 2022-09-10 15:58:05.405 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/36d898bf.npz mode data from file cache.
# 2022-09-10 15:58:05.503 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/af7059be.npz mode data from file cache.
# 2022-09-10 15:58:05.602 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aa2134a5.npz mode data from file cache.
# 2022-09-10 15:58:05.703 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/3daa332f.npz mode data from file cache.
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2022-09-10 15:58:05.809 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/cbc69aad.npz mode data from file cache.
# 2022-09-10 15:58:05.925 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d88e531c.npz mode data from file cache.
# 2022-09-10 15:58:06.032 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bfe27829.npz mode data from file cache.
# 2022-09-10 15:58:06.139 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/b604ff01.npz mode data from file cache.
# 2022-09-10 15:58:06.244 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/6453e781.npz mode data from file cache.
# 2022-09-10 15:58:06.343 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/701c0cac.npz mode data from file cache.
# 2022-09-10 15:58:06.438 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/5d807a39.npz mode data from file cache.
# 2022-09-10 15:58:06.534 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/36d898bf.npz mode data from file cache.
# 2022-09-10 15:58:06.630 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/af7059be.npz mode data from file cache.
# 2022-09-10 15:58:06.724 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aa2134a5.npz mode data from file cache.
# 2022-09-10 15:58:06.821 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/3daa332f.npz mode data from file cache.

# %% [markdown]
# ## Group index
#
# You can also compute the group index for a waveguide.

# %%
import gdsfactory.simulation.gtidy3d as gt
import numpy as np
import matplotlib.pyplot as plt

nm = 1e-3

ng = gt.modes.group_index(
    wg_width=500 * nm,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
print(ng)
# Out:
# 2022-09-10 15:58:07.840 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/534e038e.npz mode data from file cache.
# 2022-09-10 15:58:07.941 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9632c7cb.npz mode data from file cache.
# 2022-09-10 15:58:08.042 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ee6112c0.npz mode data from file cache.
# 4.16956337679879

# %%
wavelengths = np.arange(1500, 1601, 50) * 1e-3
wg_widths = np.arange(400, 601, 50) * 1e-3

wg_settings = dict(
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)

for wg_width in wg_widths:
    ng = [
        gt.modes.group_index(wavelength=wavelength, wg_width=wg_width, **wg_settings)
        for wavelength in wavelengths
    ]
    plt.plot(wavelengths, ng, label=f"{wg_width*1e3}")

plt.legend()
plt.xlabel("Wavelength (um)")
plt.xlabel("ng")
# Out:
# 2022-09-10 15:58:08.158 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/6f4d3cd7.npz mode data from file cache.
# 2022-09-10 15:58:08.256 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bd4c384f.npz mode data from file cache.
# 2022-09-10 15:58:08.352 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/28144d52.npz mode data from file cache.
# 2022-09-10 15:58:08.454 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/17e81e4c.npz mode data from file cache.
# 2022-09-10 15:58:08.552 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c2bb5e05.npz mode data from file cache.
# 2022-09-10 15:58:08.651 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8be1b1b4.npz mode data from file cache.
# 2022-09-10 15:58:08.751 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9a215eee.npz mode data from file cache.
# 2022-09-10 15:58:08.850 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e4329efe.npz mode data from file cache.
# 2022-09-10 15:58:08.949 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/42f10c0c.npz mode data from file cache.
# 2022-09-10 15:58:09.064 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/13844833.npz mode data from file cache.
# 2022-09-10 15:58:09.164 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/4e8484ba.npz mode data from file cache.
# 2022-09-10 15:58:09.261 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9429b40d.npz mode data from file cache.
# 2022-09-10 15:58:09.362 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/be624d43.npz mode data from file cache.
# 2022-09-10 15:58:09.460 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/cc1549de.npz mode data from file cache.
# 2022-09-10 15:58:09.556 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/79a1d52e.npz mode data from file cache.
# 2022-09-10 15:58:09.664 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/0046583f.npz mode data from file cache.
# 2022-09-10 15:58:09.767 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/a9d652ff.npz mode data from file cache.
# 2022-09-10 15:58:09.878 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/0df605d6.npz mode data from file cache.
# 2022-09-10 15:58:09.985 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e386d28f.npz mode data from file cache.
# 2022-09-10 15:58:10.092 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/5bc85921.npz mode data from file cache.
# 2022-09-10 15:58:10.194 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/93f207d3.npz mode data from file cache.
# 2022-09-10 15:58:10.270 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/534e038e.npz mode data from file cache.
# 2022-09-10 15:58:10.346 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9632c7cb.npz mode data from file cache.
# 2022-09-10 15:58:10.425 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ee6112c0.npz mode data from file cache.
# 2022-09-10 15:58:10.524 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/730b850d.npz mode data from file cache.
# 2022-09-10 15:58:10.621 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/de3be3b3.npz mode data from file cache.
# 2022-09-10 15:58:10.715 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c1d14568.npz mode data from file cache.
# 2022-09-10 15:58:10.826 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/78d2303d.npz mode data from file cache.
# 2022-09-10 15:58:10.924 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aa0d1b7e.npz mode data from file cache.
# 2022-09-10 15:58:11.023 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e7777089.npz mode data from file cache.
# 2022-09-10 15:58:11.130 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/4396a926.npz mode data from file cache.
# 2022-09-10 15:58:11.230 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/59d4d6e4.npz mode data from file cache.
# 2022-09-10 15:58:11.333 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/dbfb2068.npz mode data from file cache.
# 2022-09-10 15:58:11.432 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/7f20089a.npz mode data from file cache.
# 2022-09-10 15:58:11.526 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/f3af4332.npz mode data from file cache.
# 2022-09-10 15:58:11.623 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/31bfd079.npz mode data from file cache.
# 2022-09-10 15:58:11.723 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/2c3f68f8.npz mode data from file cache.
# 2022-09-10 15:58:11.827 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aed7cd02.npz mode data from file cache.
# 2022-09-10 15:58:11.924 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d0502b59.npz mode data from file cache.
# 2022-09-10 15:58:12.023 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/08714841.npz mode data from file cache.
# 2022-09-10 15:58:12.127 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aa2338ad.npz mode data from file cache.
# 2022-09-10 15:58:12.223 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/7b03094d.npz mode data from file cache.
# 2022-09-10 15:58:12.326 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bd533f85.npz mode data from file cache.
# 2022-09-10 15:58:12.430 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/fa9c95e6.npz mode data from file cache.
# 2022-09-10 15:58:12.531 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/23bfd82a.npz mode data from file cache.

# %% [markdown]
# ## Bend modes
#
# You can compute bend modes specifying the bend radius.

# %%
strip_bend = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    bend_radius=3,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)

# %%
# lets plot the fundamental TE mode
strip_bend.plot_Ex(0)
strip_bend.plot_Ey(0)
# Out:
# 2022-09-10 15:58:12.872 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/be958cac.npz mode data from file cache.

# %%
# lets plot the fundamental TM mode
strip_bend.plot_Ex(1)
strip_bend.plot_Ey(1)

# %% [markdown]
# ## Bend loss
#
# You can also compute the losses coming from the mode mismatch from the bend into a straight waveguide.
# To compute the bend loss due to mode mismatch you can calculate the mode overlap of the straight mode and the bent mode.
# Because there are two mode mismatch interfaces the total loss due to mode mismatch will be squared (from bend to straight and from straight to bend).
#
# ![](https://i.imgur.com/M1Yysdr.png)
#
# [from paper](https://ieeexplore.ieee.org/ielaam/50/8720127/8684870-aam.pdf)

# %%
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt

r, integral = gt.modes.sweep_bend_loss(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
    bend_radius_min=2.0,
    bend_radius_max=5,
    steps=4,
    mode_index=0,
)

plt.plot(r, integral, ".")
plt.xlabel("bend radius (um)")
plt.ylabel("Transmission")
plt.show()
# Out:
# 0it [00:00, ?it/s]
# 2022-09-10 15:58:14.774 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/534e038e.npz mode data from file cache.
# 2022-09-10 15:58:14.874 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/cdf8a2c5.npz mode data from file cache.
# 2022-09-10 15:58:14.961 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/be958cac.npz mode data from file cache.
# 2022-09-10 15:58:15.086 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8c18cbe1.npz mode data from file cache.
# 2022-09-10 15:58:15.203 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ba280765.npz mode data from file cache.

# %% [markdown]
# ## Waveguide coupler
#
# You can also compute the modes of a waveguide coupler.
#
# ```
#         wg_width1     wg_width2
#         <------->     <------->
#          _______   |   _______   __
#         |       |  |  |       | |
#         |       |  |  |       | |
#         |       |_____|       | | wg_thickness
#         |slab_thickness       | |
#         |_____________________| |__
#                 <----->
#                   gap
#
#
# ```

# %%
si = gt.modes.si
sio2 = gt.modes.sio2
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=100 * nm,
    ncore=si,
    nclad=sio2,
)
c.plot_index()

# %%
c.plot_Ex(0)
# Out:
# 2022-09-10 15:58:17.174 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:389 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9fb5b7fe.npz mode data to file cache.

# %%
c.plot_Ex(1)

# %%
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=si,
    nclad=sio2,
)
c.plot_index()

# %%
c.plot_Ex(0)
# Out:
# 2022-09-10 15:58:19.938 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:389 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/1948847c.npz mode data to file cache.

# %%
c.plot_Ex(1)

# %%
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt

# %%
nm = 1e-3
si = gt.modes.si
sio2 = gt.modes.sio2
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=si,
    nclad=sio2,
)
c.plot_index()

# %%
gaps = [150, 200, 250, 300]
coupling_length = [
    gt.modes.WaveguideCoupler(
        wavelength=1.55,
        wg_width1=500 * nm,
        wg_width2=500 * nm,
        gap=gap * nm,
        wg_thickness=220 * nm,
        slab_thickness=0 * nm,
        ncore=si,
        nclad=sio2,
    ).find_coupling(power_ratio=1)
    for gap in gaps
]
# Out:
# 2022-09-10 15:58:22.824 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:389 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/46ada42d.npz mode data to file cache.
# 2022-09-10 15:58:22.848 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:347 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/1948847c.npz mode data from file cache.
# 2022-09-10 15:58:24.305 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:389 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8bd27d56.npz mode data to file cache.
# 2022-09-10 15:58:25.491 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:389 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/457730ef.npz mode data to file cache.

# %%
plt.plot(gaps, coupling_length, ".")
plt.xlabel("gap (nm)")
plt.ylabel("100% coupling length (um)")
